# %%
import numpy as np
import pandas as pd

# %%
cities = ['İstanbul', 'Malatya', 'Ankara','İzmir','Aydın']

# %%
df = pd.DataFrame(cities)
df
# Out:
#           0
# 0  İstanbul
# 1   Malatya
# 2    Ankara
# 3     İzmir
# 4     Aydın

# %%
df[1] = [34,44,6,35,9]
df
# Out:
#           0   1
# 0  İstanbul  34
# 1   Malatya  44
# 2    Ankara   6
# 3     İzmir  35
# 4     Aydın   9

# %%
df.columns = ['Şehir','Plaka']
df
# Out:
#       Şehir  Plaka
# 0  İstanbul     34
# 1   Malatya     44
# 2    Ankara      6
# 3     İzmir     35
# 4     Aydın      9

# %%
data = {
    "Şehir" : ['İstanbul', 'Malatya', 'Ankara','İzmir','Aydın'],
    "Plaka" : [34,44,6,35,9]
}

df1 = pd.DataFrame(data)
df1
# Out:
#       Şehir  Plaka
# 0  İstanbul     34
# 1   Malatya     44
# 2    Ankara      6
# 3     İzmir     35
# 4     Aydın      9

# %%
# Tarih işlemleri
#yyyy-mm-dd
dates = pd.date_range(start='2025-09-06',end="2025-10-10")
dates
# Out:
# DatetimeIndex(['2025-09-06', '2025-09-07', '2025-09-08', '2025-09-09',
#                '2025-09-10', '2025-09-11', '2025-09-12', '2025-09-13',
#                '2025-09-14', '2025-09-15', '2025-09-16', '2025-09-17',
#                '2025-09-18', '2025-09-19', '2025-09-20', '2025-09-21',
#                '2025-09-22', '2025-09-23', '2025-09-24', '2025-09-25',
#                '2025-09-26', '2025-09-27', '2025-09-28', '2025-09-29',
#                '2025-09-30', '2025-10-01', '2025-10-02', '2025-10-03',
#                '2025-10-04', '2025-10-05', '2025-10-06', '2025-10-07',
#                '2025-10-08', '2025-10-09', '2025-10-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates1 = pd.date_range('today',periods = 7)
dates1
# Out:
# DatetimeIndex(['2025-09-21 22:20:55.758961', '2025-09-22 22:20:55.758961',
#                '2025-09-23 22:20:55.758961', '2025-09-24 22:20:55.758961',
#                '2025-09-25 22:20:55.758961', '2025-09-26 22:20:55.758961',
#                '2025-09-27 22:20:55.758961'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates2 = pd.date_range(start = '2023-08-10', periods = 7)
dates2
# Out:
# DatetimeIndex(['2023-08-10', '2023-08-11', '2023-08-12', '2023-08-13',
#                '2023-08-14', '2023-08-15', '2023-08-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
M = np.random.randint(200,780,49).reshape(7,7)
M
# Out:
# array([[294, 427, 711, 284, 693, 359, 367],
#        [484, 258, 412, 720, 283, 534, 661],
#        [621, 295, 543, 413, 554, 422, 428],
#        [411, 685, 320, 543, 637, 643, 721],
#        [688, 378, 479, 540, 336, 655, 589],
#        [588, 343, 729, 702, 584, 267, 778],
#        [201, 240, 361, 548, 712, 258, 482]], dtype=int32)

# %%
dframe = pd.DataFrame(M,index = dates2)
dframe
# Out:
#               0    1    2    3    4    5    6
# 2023-08-10  294  427  711  284  693  359  367
# 2023-08-11  484  258  412  720  283  534  661
# 2023-08-12  621  295  543  413  554  422  428
# 2023-08-13  411  685  320  543  637  643  721
# 2023-08-14  688  378  479  540  336  655  589
# 2023-08-15  588  343  729  702  584  267  778
# 2023-08-16  201  240  361  548  712  258  482

# %%
dframe.columns = ['C1','C2','C3','C4','C5','C6','C7']
dframe
# Out:
#              C1   C2   C3   C4   C5   C6   C7
# 2023-08-10  294  427  711  284  693  359  367
# 2023-08-11  484  258  412  720  283  534  661
# 2023-08-12  621  295  543  413  554  422  428
# 2023-08-13  411  685  320  543  637  643  721
# 2023-08-14  688  378  479  540  336  655  589
# 2023-08-15  588  343  729  702  584  267  778
# 2023-08-16  201  240  361  548  712  258  482

# %%
# list comprosion yöntemi
dframe.columns = [f'C1{i}'for i in range(1,8)]
dframe
# Out:
#             C11  C12  C13  C14  C15  C16  C17
# 2023-08-10  294  427  711  284  693  359  367
# 2023-08-11  484  258  412  720  283  534  661
# 2023-08-12  621  295  543  413  554  422  428
# 2023-08-13  411  685  320  543  637  643  721
# 2023-08-14  688  378  479  540  336  655  589
# 2023-08-15  588  343  729  702  584  267  778
# 2023-08-16  201  240  361  548  712  258  482

# %%
# Sıralama işlemleri
# C1 kolonuna göre artan bir şekilde sıralama

dframe.sort_values(by='C1')    # ascending
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26320\1359625435.py in ?()
#       1 # Sıralama işlemleri
#       2 # C1 kolonuna göre artan bir şekilde sıralama
#       3
# ----> 4 dframe.sort_values(by='C1')
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'C1'
